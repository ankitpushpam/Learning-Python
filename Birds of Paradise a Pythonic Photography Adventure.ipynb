# %%
rarebirds = {
    'Gold-crested Toucan': {
        'Height (m)': 1.1,
        'Weight (kg)': 35,
        'Color': 'Gold',
        'Endangered': True,
        'Aggressive': True},

    'Pearlescent Kingfisher': {
        'Height (m)': 0.25,
        'Weight (kg)': 0.5,
        'Color': 'White',
        'Endangered': False,
        'Aggressive': False},

    'Four-metre Hummingbird': {
        'Height (m)': 0.6,
        'Weight (kg)': 0.5,
        'Color': 'Blue',
        'Endangered': True,
        'Aggressive': False},

     'Giant Eagle': {
        'Height (m)': 1.5,
        'Weight (kg)': 52,
        'Color': 'Black and White',
        'Endangered': True,
        'Aggressive': True},   
    
    'Ancient Vulture': {
        'Height (m)': 2.1,
        'Weight (kg)': 70,
        'Color': 'Brown',
        'Endangered': False,
        'Aggressive': False}
}

birdlocation = ['In the canopy directly above our heads' , 
                 'Between my 6 and 9 o’clock above' , 
                 'Between my 9 and 12 o’clock above' , 
                 'Between my 12 and 3 o’clock above', 
                 'Between my 3 and 6 o’clock above', 
                 'In a nest on the ground', 
                 'Right behind you' ]
codes = { 'In the canopy directly above our heads': '111',
                      'Between my 6 and 9 o’clock above': '110' , 
                      'Between my 9 and 12 o’clock above': '101' , 
                      'Between my 12 and 3 o’clock above': '101' , 
                      'Between my 3 and 6 o’clock above': '100', 
                      'In a nest on the ground': '011' , 
                      'Right behind you': '010'  }

actions = ['Back Away', 'Cover our Heads',  'Take a Photograph']

print(rarebirds['Giant Eagle']['Aggressive'])

for k,v in rarebirds.items():
    print(v)
    if v['Aggressive'] == True:
        print(actions[1])
    elif v['Endangered'] == True:
        print(actions[0]) 
    else:
        print(actions[2])

for k,v in codes.items():
     print(k + 'value of this in the binary form is ' + v)

for k,v in rarebirds.items():
    rarebirds[k]['seen'] = 'False'
    print(v)

encounter = True
sighting = ''
rarebirdsList = list(rarebirds.keys())

#Location of the bird




while (encounter == True ):
    sighting = input('What do you see?')
    sighting = sighting.lower()
    print(sighting)
    code = input('Where do you see it?')
    location = codes[code]
    print("So you've seen a", sighting, location, "My goodness.")
    for i in rarebirdsList:
        l = i.lower()
        if l == sighting:
            print('this is one of the birds we’re looking for!')
            if rarebirds[i]['Aggressive'] == True:
                print(actions[0] + ' ' + ', and' + ' ' + actions[1] + ' , ' + sighting + ' is at location ', location)
            elif rarebirds[i]['Endangered'] == True:
                print(actions[0] + ' ' + ', and' + ' ' + actions[2] + ' , ' + sighting + ' is at location ', location)
            else:
                print('we need to photograph the ultra rare', sighting + ' is at location ', location  )
            encounter = False
            break
        else:
            print('that’s not one of the birds we’re looking for')
# Out:
# True
# {'Height (m)': 1.1, 'Weight (kg)': 35, 'Color': 'Gold', 'Endangered': True, 'Aggressive': True}
# Cover our Heads
# {'Height (m)': 0.25, 'Weight (kg)': 0.5, 'Color': 'White', 'Endangered': False, 'Aggressive': False}
# Take a Photograph
# {'Height (m)': 0.6, 'Weight (kg)': 0.5, 'Color': 'Blue', 'Endangered': True, 'Aggressive': False}
# Back Away
# {'Height (m)': 1.5, 'Weight (kg)': 52, 'Color': 'Black and White', 'Endangered': True, 'Aggressive': True}
# Cover our Heads
# {'Height (m)': 2.1, 'Weight (kg)': 70, 'Color': 'Brown', 'Endangered': False, 'Aggressive': False}
# Take a Photograph
# In the canopy directly above our headsvalue of this in the binary form is 111
# Between my 6 and 9 o’clock abovevalue of this in the binary form is 110
# Between my 9 and 12 o’clock abovevalue of this in the binary form is 101
# Between my 12 and 3 o’clock abovevalue of this in the binary form is 101
# Between my 3 and 6 o’clock abovevalue of this in the binary form is 100
# ...
